# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\kiit\appdata\local\programs\python\python313\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.10.5)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

def get_weather(city, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    
    params = {
        "q": city,
        "appid": api_key,
        "units": "metric"   # Celsius
    }
    
    response = requests.get(url, params=params)
    return response.json()


def main():
    print("=================================")
    print("        WEATHER APPLICATION")
    print("=================================")

    api_key = api_key = "3c87d91aea459600ac46615863c4686c"

    city = input("Enter city name: ")

    if city.strip() == "":
        print("City name cannot be empty!")
        return

    try:
        data = get_weather(city, api_key)

        if data["cod"] != 200:
            print("City not found or API error!")
            return

        temperature = data["main"]["temp"]
        humidity = data["main"]["humidity"]
        weather_desc = data["weather"][0]["description"]
        wind_speed = data["wind"]["speed"]

        print("\n----- WEATHER DETAILS -----")
        print(f"City: {city}")
        print(f"Temperature: {temperature} °C")
        print(f"Humidity: {humidity}%")
        print(f"Weather: {weather_desc.capitalize()}")
        print(f"Wind Speed: {wind_speed} m/s")

    except Exception as e:
        print("Something went wrong:", e)


# Run the app
main()
# Out:
# =================================
#         WEATHER APPLICATION
# =================================
# Enter city name:  delhi
# City not found or API error!

# %%
import requests

def get_weather(city, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    
    params = {
        "q": city,
        "appid": api_key,
        "units": "metric"   # Celsius
    }
    
    response = requests.get(url, params=params)
    return response.json()


def main():
    print("=================================")
    print("        WEATHER APPLICATION")
    print("=================================")

    api_key = api_key = "3c87d91aea459600ac46615863c4686c"

    city = input("Enter city name: ")

    if city.strip() == "":
        print("City name cannot be empty!")
        return

    try:
        data = get_weather(city, api_key)

        if data["cod"] != 200:
            print("City not found or API error!")
        
            return

        temperature = data["main"]["temp"]
        humidity = data["main"]["humidity"]
        weather_desc = data["weather"][0]["description"]
        wind_speed = data["wind"]["speed"]

        print("\n----- WEATHER DETAILS -----")
        print(f"City: {city}")
        print(f"Temperature: {temperature} °C")
        print(f"Humidity: {humidity}%")
        print(f"Weather: {weather_desc.capitalize()}")
        print(f"Wind Speed: {wind_speed} m/s")

    except Exception as e:
        print("Something went wrong:", e)


# Run the app
main()
# Out:
# =================================
#         WEATHER APPLICATION
# =================================
# Enter city name:  delhi
# City not found or API error!

# %%
import requests

api_key = "3c87d91aea459600ac46615863c4686c"

url = f"https://api.openweathermap.org/data/2.5/weather?q=Delhi&appid={api_key}&units=metric"

response = requests.get(url)
print(response.json())
# Out:
# {'coord': {'lon': 77.2167, 'lat': 28.6667}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 19.05, 'feels_like': 18.55, 'temp_min': 19.05, 'temp_max': 19.05, 'pressure': 1013, 'humidity': 59, 'sea_level': 1013, 'grnd_level': 988}, 'visibility': 5000, 'wind': {'speed': 1.54, 'deg': 270}, 'clouds': {'all': 0}, 'dt': 1771078006, 'sys': {'type': 1, 'id': 9165, 'country': 'IN', 'sunrise': 1771032648, 'sunset': 1771072804}, 'timezone': 19800, 'id': 1273294, 'name': 'Delhi', 'cod': 200}

# %%
import requests

def get_weather(city, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    
    params = {
        "q": city,
        "appid": api_key,
        "units": "metric"   # Celsius
    }
    
    response = requests.get(url, params=params)
    return response.json()


def main():
    print("=================================")
    print("        WEATHER APPLICATION")
    print("=================================")

    api_key = "3c87d91aea459600ac46615863c4686c"
    city = input("Enter city name: ")

    if city.strip() == "":
        print("City name cannot be empty!")
        return

    try:
        data = get_weather(city, api_key)

        if data["cod"] != 200:
            print("City not found or API error!")
            return

        temperature = data["main"]["temp"]
        humidity = data["main"]["humidity"]
        weather_desc = data["weather"][0]["description"]
        wind_speed = data["wind"]["speed"]

        print("\n----- WEATHER DETAILS -----")
        print(f"City: {city}")
        print(f"Temperature: {temperature} °C")
        print(f"Humidity: {humidity}%")
        print(f"Weather: {weather_desc.capitalize()}")
        print(f"Wind Speed: {wind_speed} m/s")

    except Exception as e:
        print("Something went wrong:", e)


# Run the app
main()
# Out:
# =================================
#         WEATHER APPLICATION
# =================================
# Enter city name:  delhi
# ----- WEATHER DETAILS -----
# City: delhi
# Temperature: 19.05 °C
# Humidity: 59%
# Weather: Haze
# Wind Speed: 1.54 m/s
